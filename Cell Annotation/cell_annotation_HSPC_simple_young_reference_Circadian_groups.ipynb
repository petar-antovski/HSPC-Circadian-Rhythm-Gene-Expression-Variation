# %%
library(SeuratDisk)
library(Seurat)
library(SingleCellExperiment)
library(SingleR)
# Out:
# Registered S3 method overwritten by 'SeuratDisk':
#   method            from
#   as.sparse.H5Group Seurat
#
# Attaching SeuratObject
#
# Loading required package: SummarizedExperiment
#
# Loading required package: MatrixGenerics
#
# Loading required package: matrixStats
#
#
# Attaching package: ‘MatrixGenerics’
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
# ...

# %%
#Convert("/store/Projects/pantovski/Circadian/scRNA-seq/7am/write/Ambient_RNA_Cleaned/VIIam_join_inner_raw_SingleR_lognorm_200_3_10_5_scrublet_no_mt_2_UMI_5_percent_regress.h5ad", dest = "h5seurat", overwrite = TRUE)
#Convert("/store/Projects/pantovski/Circadian/scRNA-seq/11am/write/Ambient_RNA_Cleaned/XIam_join_inner_raw_SingleR_lognorm_200_3_10_5_scrublet_no_mt_2_UMI_5_percent_regress.h5ad", dest = "h5seurat", overwrite = TRUE)
#Convert("/store/Projects/pantovski/Circadian/scRNA-seq/7pm/write/Ambient_RNA_Cleaned/VIIpm_join_inner_raw_SingleR_lognorm_200_3_10_5_scrublet_no_mt_2_UMI_5_percent_regress.h5ad", dest = "h5seurat", overwrite = TRUE)
#Convert("/store/Projects/pantovski/Circadian/scRNA-seq/11pm/write/Ambient_RNA_Cleaned/XIpm_join_inner_raw_SingleR_lognorm_200_3_10_5_scrublet_no_mt_2_UMI_5_percent_regress.h5ad", dest = "h5seurat", overwrite = TRUE)

Convert("/store/Projects/pantovski/Circadian/scRNA-seq/Combined/write/Uncleaned/All_together_all_hvgo_MNN_hvgo_only_lognorm.h5ad", dest = "h5seurat", overwrite = TRUE)

All <- LoadH5Seurat("/store/Projects/pantovski/Circadian/scRNA-seq/Combined/write/Uncleaned/All_together_all_hvgo_MNN_hvgo_only_lognorm.h5seurat")
All.sce <- as.SingleCellExperiment(All)

HSPC_simple_young_SingleR_ref_8ct_matrix <- read.csv("/store/Projects/pantovski/Pre-processing_clustering_annotation/HSPC_simple_young_SingleR_ref_8ct_02182022.csv", row.names = "gene_name")
HSPC_simple_young_SingleR_ref_8ct.sce = as.SingleCellExperiment(CreateSeuratObject(HSPC_simple_young_SingleR_ref_8ct_matrix, project = 'HSPC_simple_young'))

All_pred <- SingleR(test=All.sce, ref=HSPC_simple_young_SingleR_ref_8ct.sce, labels = HSPC_simple_young_SingleR_ref_8ct.sce$orig.ident)
table(All_pred$labels)
write.csv(All_pred, file = "/store/Projects/pantovski/Circadian/scRNA-seq/Combined/write/Uncleaned/All_together_all_hvgo_MNN_hvgo_only_lognorm_cell_types.csv")
# Out:
# Warning message:
# “Unknown file type: h5ad”
# Warning message:
# “'assay' not set, setting to 'RNA'”
# Creating h5Seurat file for version 3.1.5.9900
#
# Adding X as scale.data
#
# Adding raw/X as data
#
# Adding raw/X as counts
#
# Adding meta.features from raw/var
#
# Adding dispersions-0 from scaled feature-level metadata
#
# Adding dispersions-1 from scaled feature-level metadata
#
# Adding dispersions-2 from scaled feature-level metadata
#
# Adding dispersions-3 from scaled feature-level metadata
#
# Merging dispersions_norm from scaled feature-level metadata
#
# Merging highly_variable from scaled feature-level metadata
#
# Merging mean_counts from scaled feature-level metadata
#
# Merging means from scaled feature-level metadata
#
# Merging mt from scaled feature-level metadata
#
# Merging n_cells from scaled feature-level metadata
#
# Merging n_cells_by_counts from scaled feature-level metadata
#
# Merging pct_dropout_by_counts from scaled feature-level metadata
#
# ...

# %%
Convert("/store/Projects/pantovski/Circadian/scRNA-seq/Combined/write/Uncleaned/All_together_MNN_2_UMI_5_percent_lognorm.h5ad", dest = "h5seurat", overwrite = TRUE)

All <- LoadH5Seurat("/store/Projects/pantovski/Circadian/scRNA-seq/Combined/write/Uncleaned/All_together_MNN_2_UMI_5_percent_lognorm.h5seurat")
All.sce <- as.SingleCellExperiment(All)

HSPC_simple_young_SingleR_ref_8ct_matrix <- read.csv("/store/Projects/pantovski/Pre-processing_clustering_annotation/HSPC_simple_young_SingleR_ref_8ct_02182022.csv", row.names = "gene_name")
HSPC_simple_young_SingleR_ref_8ct.sce = as.SingleCellExperiment(CreateSeuratObject(HSPC_simple_young_SingleR_ref_8ct_matrix, project = 'HSPC_simple_young'))

All_pred <- SingleR(test=All.sce, ref=HSPC_simple_young_SingleR_ref_8ct.sce, labels = HSPC_simple_young_SingleR_ref_8ct.sce$orig.ident)
table(All_pred$labels)
write.csv(All_pred, file = "/store/Projects/pantovski/Circadian/scRNA-seq/Combined/write/Uncleaned/All_together_MNN_2_UMI_5_percent_lognorm_cell_types.csv")
# Out:
# Warning message:
# “Unknown file type: h5ad”
# Warning message:
# “'assay' not set, setting to 'RNA'”
# Creating h5Seurat file for version 3.1.5.9900
#
# Adding X as scale.data
#
# Adding raw/X as data
#
# Adding raw/X as counts
#
# Adding meta.features from raw/var
#
# Adding dispersions-0 from scaled feature-level metadata
#
# Adding dispersions-1 from scaled feature-level metadata
#
# Adding dispersions-2 from scaled feature-level metadata
#
# Adding dispersions-3 from scaled feature-level metadata
#
# Merging dispersions_norm from scaled feature-level metadata
#
# Merging highly_variable from scaled feature-level metadata
#
# Merging mean_counts from scaled feature-level metadata
#
# Merging means from scaled feature-level metadata
#
# Merging mt from scaled feature-level metadata
#
# Merging n_cells from scaled feature-level metadata
#
# Merging n_cells_by_counts from scaled feature-level metadata
#
# Merging pct_dropout_by_counts from scaled feature-level metadata
#
# ...

# %%
Convert("/store/Projects/pantovski/Circadian/scRNA-seq/Combined/write/Uncleaned/All_together_MNN_2_UMI_2_percent_lognorm.h5ad", dest = "h5seurat", overwrite = TRUE)

All <- LoadH5Seurat("/store/Projects/pantovski/Circadian/scRNA-seq/Combined/write/Uncleaned/All_together_MNN_2_UMI_2_percent_lognorm.h5seurat")
All.sce <- as.SingleCellExperiment(All)

HSPC_simple_young_SingleR_ref_8ct_matrix <- read.csv("/store/Projects/pantovski/Pre-processing_clustering_annotation/HSPC_simple_young_SingleR_ref_8ct_02182022.csv", row.names = "gene_name")
HSPC_simple_young_SingleR_ref_8ct.sce = as.SingleCellExperiment(CreateSeuratObject(HSPC_simple_young_SingleR_ref_8ct_matrix, project = 'HSPC_simple_young'))

All_pred <- SingleR(test=All.sce, ref=HSPC_simple_young_SingleR_ref_8ct.sce, labels = HSPC_simple_young_SingleR_ref_8ct.sce$orig.ident)
table(All_pred$labels)
write.csv(All_pred, file = "/store/Projects/pantovski/Circadian/scRNA-seq/Combined/write/Uncleaned/All_together_MNN_2_UMI_2_percent_lognorm_cell_types.csv")
# Out:
# Warning message:
# “Unknown file type: h5ad”
# Warning message:
# “'assay' not set, setting to 'RNA'”
# Creating h5Seurat file for version 3.1.5.9900
#
# Adding X as scale.data
#
# Adding raw/X as data
#
# Adding raw/X as counts
#
# Adding meta.features from raw/var
#
# Adding dispersions-0 from scaled feature-level metadata
#
# Adding dispersions-1 from scaled feature-level metadata
#
# Adding dispersions-2 from scaled feature-level metadata
#
# Adding dispersions-3 from scaled feature-level metadata
#
# Merging dispersions_norm from scaled feature-level metadata
#
# Merging highly_variable from scaled feature-level metadata
#
# Merging mean_counts from scaled feature-level metadata
#
# Merging means from scaled feature-level metadata
#
# Merging mt from scaled feature-level metadata
#
# Merging n_cells from scaled feature-level metadata
#
# Merging n_cells_by_counts from scaled feature-level metadata
#
# Merging pct_dropout_by_counts from scaled feature-level metadata
#
# ...

# %%
Convert("/store/Projects/pantovski/Circadian/scRNA-seq/Combined/write/Uncleaned/All_together_MNN_1_UMI_2_percent_lognorm.h5ad", dest = "h5seurat", overwrite = TRUE)

All <- LoadH5Seurat("/store/Projects/pantovski/Circadian/scRNA-seq/Combined/write/Uncleaned/All_together_MNN_1_UMI_2_percent_lognorm.h5seurat")
All.sce <- as.SingleCellExperiment(All)

HSPC_simple_young_SingleR_ref_8ct_matrix <- read.csv("/store/Projects/pantovski/Pre-processing_clustering_annotation/HSPC_simple_young_SingleR_ref_8ct_02182022.csv", row.names = "gene_name")
HSPC_simple_young_SingleR_ref_8ct.sce = as.SingleCellExperiment(CreateSeuratObject(HSPC_simple_young_SingleR_ref_8ct_matrix, project = 'HSPC_simple_young'))

All_pred <- SingleR(test=All.sce, ref=HSPC_simple_young_SingleR_ref_8ct.sce, labels = HSPC_simple_young_SingleR_ref_8ct.sce$orig.ident)
table(All_pred$labels)
write.csv(All_pred, file = "/store/Projects/pantovski/Circadian/scRNA-seq/Combined/write/Uncleaned/All_together_MNN_1_UMI_2_percent_lognorm_cell_types.csv")
# Out:
# Warning message:
# “Unknown file type: h5ad”
# Warning message:
# “'assay' not set, setting to 'RNA'”
# Creating h5Seurat file for version 3.1.5.9900
#
# Adding X as scale.data
#
# Adding raw/X as data
#
# Adding raw/X as counts
#
# Adding meta.features from raw/var
#
# Adding dispersions-0 from scaled feature-level metadata
#
# Adding dispersions-1 from scaled feature-level metadata
#
# Adding dispersions-2 from scaled feature-level metadata
#
# Adding dispersions-3 from scaled feature-level metadata
#
# Merging dispersions_norm from scaled feature-level metadata
#
# Merging highly_variable from scaled feature-level metadata
#
# Merging mean_counts from scaled feature-level metadata
#
# Merging means from scaled feature-level metadata
#
# Merging mt from scaled feature-level metadata
#
# Merging n_cells from scaled feature-level metadata
#
# Merging n_cells_by_counts from scaled feature-level metadata
#
# Merging pct_dropout_by_counts from scaled feature-level metadata
#
# ...

# %%
Convert("/store/Projects/pantovski/Circadian/scRNA-seq/Combined/write/Uncleaned/All_together_all_hvgo_MNN_lognorm.h5ad", dest = "h5seurat", overwrite = TRUE)

All <- LoadH5Seurat("/store/Projects/pantovski/Circadian/scRNA-seq/Combined/write/Uncleaned/All_together_all_hvgo_MNN_lognorm.h5seurat")
All.sce <- as.SingleCellExperiment(All)

HSPC_simple_young_SingleR_ref_8ct_matrix <- read.csv("/store/Projects/pantovski/Pre-processing_clustering_annotation/HSPC_simple_young_SingleR_ref_8ct_02182022.csv", row.names = "gene_name")
HSPC_simple_young_SingleR_ref_8ct.sce = as.SingleCellExperiment(CreateSeuratObject(HSPC_simple_young_SingleR_ref_8ct_matrix, project = 'HSPC_simple_young'))

All_pred <- SingleR(test=All.sce, ref=HSPC_simple_young_SingleR_ref_8ct.sce, labels = HSPC_simple_young_SingleR_ref_8ct.sce$orig.ident)
table(All_pred$labels)
write.csv(All_pred, file = "/store/Projects/pantovski/Circadian/scRNA-seq/Combined/write/Uncleaned/All_together_all_hvgo_MNN_cell_types.csv")
# Out:
# Warning message:
# “Unknown file type: h5ad”
# Warning message:
# “'assay' not set, setting to 'RNA'”
# Creating h5Seurat file for version 3.1.5.9900
#
# Adding X as scale.data
#
# Adding raw/X as data
#
# Adding raw/X as counts
#
# Adding meta.features from raw/var
#
# Adding dispersions-0 from scaled feature-level metadata
#
# Adding dispersions-1 from scaled feature-level metadata
#
# Adding dispersions-2 from scaled feature-level metadata
#
# Adding dispersions-3 from scaled feature-level metadata
#
# Adding dispersions_norm from scaled feature-level metadata
#
# Adding highly_variable from scaled feature-level metadata
#
# Adding mean_counts from scaled feature-level metadata
#
# Adding means from scaled feature-level metadata
#
# Adding mt from scaled feature-level metadata
#
# Adding n_cells from scaled feature-level metadata
#
# Adding n_cells_by_counts from scaled feature-level metadata
#
# Adding pct_dropout_by_counts from scaled feature-level metadata
#
# ...

# %% [markdown]
# ## After looking at the ratio of the different cell types produced with the different files, the <b>All_together_all_hvgo_MNN_lognorm.h5ad</b> and the <b>All_together_all_hvgo_MNN_cell_types.csv</b> were found to produce the best ratio corresponding to the ratio of cells submitted for RNA sequencing.
